# %% [markdown]
# ## Membaca File CSV

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/data.csv")

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# Menampilkan jumlah max row
pd.options.display.max_rows
# Out:
# 60

# %%
# Mengubah default max row
pd.options.display.max_rows = 169

# %%
# Mengubah default max row
pd.options.display.max_rows = 60

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# ## Membaca JSON

# %%
df = pd.read_json("./data/data.json")

# %%
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# ## Menggunakan Parameter Pada Pandas Read

# %%
# Headernya di index ke NOL
df = pd.read_csv("./data/data.csv", sep=",", header=0)

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df = pd.read_csv("./data/data__.csv", header=0, engine='python')

# %%
df
# Out:
#     Duration__Pulse__Maxpulse__Calories
# 0                   60__110__130__409.1
# 1                   60__117__145__479.0
# 2                   60__103__135__340.0
# 3                   45__109__175__282.4
# 4                   45__117__148__406.0
# ..                                  ...
# 164                 60__105__140__290.8
# 165                 60__110__145__300.0
# 166                 60__115__145__310.2
# 167                 75__120__150__320.4
# 168                 75__125__150__330.4
#
# [169 rows x 1 columns]

# %%
df = pd.read_csv("./data/data__.csv", sep="__", header=0, engine='python')

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# ## Membaca Custom Data

# %%
data = {
    "Duration": {
        "0": 60,
        "1": 60,
        "2": 45
    },
    "Pulse": {
        "0": 110,
        "1": 117,
        "2": 103
    },
    "Maxpulse": {
        "0": 150,
        "1": 167,
        "2": 183
    },
    "Calories": {
        "0": 110,
        "1": 147,
        "2": 153
    }
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       150       110
# 1        60    117       167       147
# 2        45    103       183       153

# %% [markdown]
# ## Export Data

# %%
df.to_csv("./data/custom_data.csv")
